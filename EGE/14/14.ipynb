# %%
s = (49**7)*(7**20)-7**8-28
cnt = 0
while s != 0:
    if s % 7 == 6:
        cnt += 1
    s //= 7

print(cnt)

# %%
w = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
#print(len(w))
for i in range(0, 29):
    if i > 9:
        x = w[i-9-1]
    else:
        x = i
    t1 = f"463{x}7921"
    t2 = f"8241{x}153"

    if (int(t1, 29) + int(t2, 29)) % 28 == 0:
        print(t1, t2 )
        print(i)

#print((46307921+82410153)/28)
print((int("46307921", 29)+ int("82410153", 29)) / 28)
    #print(t1)

# %%
s = 49**6+7**18-21
cnt = 0
while s != 0:
    if s % 7 == 6:
        cnt += 1
    s //= 7

print(cnt)
