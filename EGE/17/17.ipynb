# %%
with open("EGE/17/17_1.txt", "rt") as f:
    lines = f.readlines()
l = [int(i) for i in lines]
tp = []
for p in l:
    if str(p)[-1] == str(p)[-2]:
        tp.append(p)
print(tp)
j = min(tp)
print(j)

res = []
for k in range(1, len(l)):
    a = str(l[k-1])
    b = str(l[k])
    t = [a, b]
    tri = 0
    if (int(a)%13 ==0 and int(b)%13 != 0) or (int(a)%13 !=0 and int(b)%13 == 0):
        tri = 1
    if ((a[-1] == b[-2]) or (a[-2] == b[-1])) and (tri == 1) and ((int(a)**2 + int(b)**2) <= j**2):
        res.append(int(a)**2 + int(b)**2)
print(res)
print(len(res), max(res))

# %%
with open("EGE/17/17_5.txt", "rt") as f:
    lines = f.readlines()
l = [abs(int(i)) for i in lines]
pp = []
for p in l:
    if str(p)[-1] == "3":
        pp.append(p)
print(min(pp))
print(pp)
j = []
for k in range(1, len(l)):
    a = l[k-1]
    b = l[k]
    if (((len(str(a)) == 4) and (len(str(b)) != 4)) or (((len(str(a)) != 4)) and (len(str(b)) == 4))) and ((a**2 + b**2)%23 == 0):
        print(a, b)
        j.append(a**2 + b**2)

print(len(j), max(j))

print((10074**2+4761**2)%23==0)
print(1007)

# %%
with open("EGE/17/17_1.txt", "rt") as f:
    lines = f.readlines()
l = [abs(int(i)) for i in lines]
# for p in l:
#     if str(p)[-3::] == "123":
#         print(p)
m  = 66123
j = []
for k in range(1, len(l)-1):
    a = l[k-1]
    b = l[k]
    c = l[k+1]
    t = [a, b, c]
    pyat = 0
    tri = 0
    for k in t:
        if len(str(k)) == 5:
            pyat += 1
        if k % 3 == 0:
            tri += 1
    if sum(t) > m and pyat >= 2 and tri == 1:
        print( t)
        j.append(sum(t))
print(len(j), max(j))
