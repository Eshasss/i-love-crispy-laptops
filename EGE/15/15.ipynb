# %%
count = 0
for a in range(5000):
    k=0
    for x in range(1, 501):
        for y in range(1, 501):
            if ((x*y<a) or (x<7*y) or (343<x))==1:
                k += 1
    if k==500*500:
        print(a)
        # count += 1
# print(count)

# %%
def f(x, a1, a2):
  P = (225<= x <= 464)
  Q = (140 <= x <= 315)
  A = (a1 <= x <= a2)

  return (P) <=(((Q)and(not A)) <=(not(P)))

ans = 1000
for a1 in range(1, 600):
  for a2 in range(a1 + 1, 600):
    if all(f(x, a1, a2) == 1 for x in range(-10, 1201)):
      ans = min(ans, a2 - a1)

print(ans)
# Out:
# 90

# %%
for a in range(0, 200):
    k = True
    for x in range(0, 200):
        for y in range(0, 200):
            if ((3*y-x > 12) or (2*x + 6*y >= 72) or (x > 24) or (x * y < a)) != 1:
                k = False
    if k == True:
        print(a)

# %%
def f(x, a1, a2):
  P = (225<= x <= 464)
  Q = (140 <= x <= 315)
  A = (a1 <= x <= a2)

  # return (P) <=((Q)and(not A) <= not(P))

ans = 1000
for a1 in range(1, 200):
  for a2 in range(a1 + 1, 200):
    if all(f(x, a1, a2) == 1 for x in range(-10, 201)):
      ans = min(ans, a2 - a1)

print(ans)

# %%
for A in range(0, 300):
    k=0
    for x in range(1, 301):
        for y in range(1, 301):
            if ((x >= 8) or (A < x * y) or (y <= 7)):
                k=k+1
    if k==300*300:
        print(A)

count = 0
for a in range(100):
    k=0
    for x in range(1, 101):
        for y in range(1, 101):
            if ((x<a) <= (x*x<=169) and ((y*y<16) <= (y<=a))) == 1:
                k += 1
    if k==100*100:
        count += 1
print(count)


#

count = 0
for a in range(1000):
    k=0
    for x in range(1, 1001):
        for y in range(1, 1001):
            if ((x*y<a) or (x<7*y) or (343<x))==1:
                k += 1
    if k==1000*1000:
        print(a)
        # count += 1
print(count)



for a in range(100000):
    k=0
    for x in range(1, 101):
        for y in range(1, 101):
            if ((x + y*2>48) or (y>x) or (x+3*y<a))==0:
                k += 1
    if k==100*100:
        print(a)
        count += 1
print(count)

# %%
def dl(n, m):
    if n%m==0:
        return True
    return False

for a in range(1, 10000):
    s = 0
    for x in range(1000):
        if (a<50) and ((not(dl(x, a))) <= ((dl(x, 10) <= (not(dl(x, 18)))))) == 1:
            s += 1
    if s == 1000:
        print(a)
