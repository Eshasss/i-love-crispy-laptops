# %%
# !pip install razdel
# Out:
# Requirement already satisfied: razdel in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.5.0)

# %% [markdown]
# ## Импорты

# %%
from string import punctuation
from razdel import sentenize
from razdel import tokenize as razdel_tokenize
import numpy as np
from IPython.display import Image
from IPython.core.display import HTML 
from scipy.sparse import lil_matrix
from collections import Counter
import nltk
from nltk.tokenize import sent_tokenize
nltk.download('stopwords')  
nltk.download('punkt')
nltk.download('punkt_tab')

# %%
news = open('lenta.txt', encoding="utf-8").read()

# %%
def normalize(text):
    normalized_text = [word.text.strip(punctuation) for word \
                                                            in razdel_tokenize(text)]
    normalized_text = [word.lower() for word in normalized_text if word and len(word) < 20 ]
    return normalized_text

# %%
norm_news = normalize(news)

# %%
vocab_news = Counter(norm_news)

# %%
probas_news = Counter({word:c/len(norm_news) for word, c in vocab_news.items()})
probas_news.most_common(20)

# %%
sentences_news = [['<start>'] + normalize(text) + ['<end>'] for text in sent_tokenize(news[:5000000], language = "russian")]

# %%
def ngrammer(tokens, n=3):
    ngrams = []
    for i in range(0,len(tokens)-n+1):
        ngrams.append(' '.join(tokens[i:i+n]))
    return ngrams

# %%
unigrams_news = Counter()
bigrams_news = Counter()

for sentence in sentences_news:
    unigrams_news.update(sentence)
    bigrams_news.update(ngrammer(sentence))

# %%
unigrams_news

# %%
bigrams_news
# Out:
# Counter({'<start> об этом': 657,
#          '<start> по словам': 626,
#          'со ссылкой на': 606,
#          '<start> как сообщает': 600,
#          'сообщает риа новости': 500,
#          '<start> кроме того': 452,
#          'в связи с': 417,
#          'риа новости <end>': 361,
#          'по его словам': 355,
#          '<start> по его': 336,
#          '<start> напомним что': 331,
#          'о том что': 327,
#          'в настоящее время': 312,
#          '<start> по данным': 310,
#          '<start> по мнению': 293,
#          'в том числе': 248,
#          '<start> при этом': 224,
#          'риа новости со': 203,
#          'как сообщает риа': 198,
#          'новости со ссылкой': 198,
#          '<start> как сообщили': 181,
#          'в соответствии с': 175,
#          '<start> в настоящее': 172,
#          'риа новости в': 169,
#          'в то же': 168,
#          'то же время': 168,
#          '<start> как сообщил': 163,
#          '<start> в то': 157,
#          'на северном кавказе': 156,
#          'в ближайшее время': 156,
#          'до сих пор': 153,
#          '<start> в результате': 151,
#          '<start> между тем': 148,
#          '<start> в частности': 146,
#          'передает риа новости': 144,
#          'в том что': 143,
#          'после того как': 140,
#          '<start> таким образом': 140,
#          '<start> по информации': 131,
#          'миллионов долларов <end>': 129,
#          'тем не менее': 119,
#          '2000 года <end>': 117,
#          'как сообщает агентство': 117,
#          'по московскому времени': 107,
#          'как сообщает итар-тасс': 105,
#          '<start> тем не': 105,
#          '<start> как передает': 104,
#          '<start> вместе с': 102,
#          'отечество вся россия': 102,
#          '<start> как заявил': 102,
#          'для того чтобы': 101,
#          'агентство риа новости': 97,
#          'итар-тасс со ссылкой': 96,
#          '<start> в ходе': 95,
#          'об этом сообщает': 95,
#          'вместе с тем': 94,
#          'на то что': 93,
#          'bank of new': 92,
#          'of new york': 92,
#          'об этом сообщил': 92,
#          'в чечне <end>': 89,
#          '<start> по сведениям': 86,
#          'по его мнению': 85,
#          'января 2000 года': 84,
#          'сообщили риа новости': 83,
#          'об этом риа': 82,
#          'этом риа новости': 82,
#          'по предварительным данным': 81,
#          'сообщает агентство риа': 81,
#          '<start> по сообщению': 79,
#          'в этом году': 79,
#          'в свою очередь': 77,
#          'ссылкой на пресс-службу': 76,
#          'по борьбе с': 75,
#          'сообщает итар-тасс со': 74,
#          'как сообщили риа': 72,
#          'в 2000 году': 72,
#          '<start> в связи': 71,
#          'в минувший вторник': 71,
#          'в прошлом году': 70,
#          'с тем что': 69,
#          'напомним что в': 67,
#          'в россии <end>': 65,
#          '<start> он также': 65,
#          'на пресс-конференции в': 64,
#          'на прошлой неделе': 64,
#          '<start> предполагается что': 64,
#          '<start> по предварительным': 64,
#          'в минувший четверг': 64,
#          'интерфакс со ссылкой': 63,
#          'в москве <end>': 63,
#          'министр иностранных дел': 63,
#          '<start> однако в': 62,
#          'риа новости сообщили': 61,
#          'возбуждено уголовное дело': 60,
#          'он отметил что': 59,
#          'россии владимир путин': 59,
#          'сообщил риа новости': 59,
#          'том числе и': 59,
#          'в минувший понедельник': 59,
#          'как сообщает интерфакс': 58,
#          'в минувшее воскресенье': 58,
#          'журналистам риа новости': 58,
#          'в последнее время': 57,
#          'в первую очередь': 57,
#          'сообщает associated press': 57,
#          'сообщает reuters <end>': 57,
#          '<start> в этом': 56,
#          'связи с этим': 56,
#          'на сегодняшний день': 55,
#          'во главе с': 55,
#          'речь идет о': 55,
#          'в настоящий момент': 55,
#          'в минувшую среду': 55,
#          'по сравнению с': 54,
#          'он подчеркнул что': 54,
#          '<start> в соответствии': 54,
#          '<start> после этого': 53,
#          'декабря 1999 года': 53,
#          '<start> однако по': 53,
#          'associated press <end>': 53,
#          'федеральное агентство новостей': 53,
#          'об этом заявил': 52,
#          'кроме того в': 52,
#          'в одном из': 52,
#          'во вторник в': 52,
#          '<start> несмотря на': 52,
#          'не было <end>': 51,
#          'блока отечество вся': 51,
#          'сказал он <end>': 51,
#          'сообщает интерфакс со': 51,
#          'в то время': 51,
#          '1999 года <end>': 51,
#          '<start> в течение': 50,
#          'тысяч долларов <end>': 50,
#          'в общей сложности': 50,
#          'на встрече с': 50,
#          'в ночь на': 49,
#          'тысяч человек <end>': 49,
#          '<start> однако как': 49,
#          'в среду в': 48,
#          'так и не': 48,
#          'новости сообщили в': 48,
#          'на пост президента': 48,
#          'сообщил также что': 48,
#          'сих пор не': 48,
#          'союза правых сил': 48,
#          'сообщил что в': 47,
#          'северном кавказе <end>': 47,
#          '<start> в случае': 47,
#          '<start> тем временем': 46,
#          'сообщает рбк <end>': 46,
#          'миллиарда долларов <end>': 45,
#          'в четверг в': 45,
#          'рао еэс россии': 45,
#          'на 2000 год': 45,
#          'в 1998 году': 44,
#          '<start> он подчеркнул': 44,
#          'риа новости что': 44,
#          'он заявил что': 44,
#          'миллионов рублей <end>': 43,
#          'радиостанция эхо москвы': 43,
#          'владимир путин <end>': 43,
#          '1 января 2000': 43,
#          'в 1999 году': 43,
#          '<start> во вторник': 42,
#          'министр внутренних дел': 42,
#          '<start> он сообщил': 42,
#          '<start> на месте': 42,
#          '<start> он отметил': 42,
#          'по этому поводу': 42,
#          'new york times': 41,
#          '<start> в интервью': 41,
#          '<start> более того': 41,
#          'также сообщил что': 41,
#          '<start> в четверг': 41,
#          'сообщает агентство прайм-тасс': 41,
#          'ссылкой на источники': 40,
#          '<start> ожидается что': 40,
#          'а также в': 40,
#          'по местному времени': 40,
#          'несмотря на то': 40,
#          'в пятницу в': 40,
#          'как передает риа': 40,
#          'в частности в': 40,
#          'в депутаты госдумы': 40,
#          'сообщает интерфакс <end>': 40,
#          'по обвинению в': 39,
#          'то время как': 39,
#          'с точки зрения': 39,
#          'уголовное дело по': 39,
#          'сообщает федеральное агентство': 39,
#          'и о президента': 39,
#          'в понедельник в': 38,
#          '<start> в рамках': 38,
#          'как стало известно': 38,
#          'он сообщил что': 38,
#          '<start> как сообщила': 38,
#          'по меньшей мере': 38,
#          'том что в': 38,
#          'в государственную думу': 38,
#          '<start> во время': 37,
#          'на источники в': 37,
#          '<start> один из': 37,
#          '<start> по их': 37,
#          'радиостанции эхо москвы': 37,
#          'эхо москвы <end>': 37,
#          'по словам представителя': 37,
#          'в 1997 году': 36,
#          'кроме того по': 36,
#          'его словам в': 36,
#          'как сообщил риа': 36,
#          'между россией и': 36,
#          'риа новости сообщил': 36,
#          'к тому же': 36,
#          'миллиона долларов <end>': 36,
#          'информационная служба ввс': 36,
#          'в ближайшие дни': 35,
#          'миллиардов долларов <end>': 35,
#          'в тот же': 35,
#          'мэр москвы юрий': 35,
#          'москвы юрий лужков': 35,
#          'в 1996 году': 35,
#          'российской федерации <end>': 35,
#          '<start> в среду': 35,
#          '<start> в качестве': 35,
#          'рубля за доллар': 35,
#          'новостей со ссылкой': 35,
#          'более чем на': 34,
#          'по их мнению': 34,
#          'в интернете <end>': 34,
#          'отметил что в': 34,
#          'союз правых сил': 34,
#          'агентство военных новостей': 34,
#          'по отношению к': 34,
#          'рублей за тонну': 34,
#          '<start> что касается': 34,
#          '<start> такое решение': 34,
#          '<start> в свою': 33,
#          '<start> как стало': 33,
#          'до тех пор': 33,
#          'как сообщили в': 33,
#          '<start> он заявил': 33,
#          'войск на северном': 33,
#          'в москве и': 32,
#          'тем что в': 32,
#          'в свое время': 32,
#          'тот же день': 32,
#          'заявил что в': 32,
#          'по налогам и': 32,
#          '1998 года <end>': 32,
#          'россии и белоруссии': 32,
#          'по этому вопросу': 32,
#          'объединенной группировки войск': 32,
#          'операции в чечне': 32,
#          'премьер-министр россии владимир': 31,
#          'не исключено что': 31,
#          'на территории чечни': 31,
#          'тех пор пока': 31,
#          '<start> всего в': 31,
#          'может привести к': 31,
#          'за то что': 31,
#          'в 1995 году': 31,
#          'подчеркнул он <end>': 31,
#          'в прямом эфире': 31,
#          '<start> как сообщило': 31,
#          'налогам и сборам': 31,
#          '<start> в понедельник': 31,
#          'с тем чтобы': 31,
#          'миллиардов рублей <end>': 31,
#          'об этом в': 31,
#          'по крайней мере': 30,
#          'в результате взрыва': 30,
#          'в правоохранительных органах': 30,
#          'связи с тем': 30,
#          'что в ходе': 30,
#          'принять участие в': 30,
#          'в отличие от': 30,
#          '<start> в этой': 30,
#          'новости в пресс-службе': 30,
#          'выразил надежду что': 30,
#          '<start> среди них': 30,
#          'в этой связи': 30,
#          'сообщает эхо москвы': 30,
#          'агентство associated press': 30,
#          'с 1 января': 30,
#          'сообщает информационная служба': 30,
#          'федеральных сил <end>': 29,
#          'боевых действий в': 29,
#          'что в настоящее': 29,
#          '<start> в заявлении': 29,
#          'настоящее время в': 29,
#          'по словам представителей': 29,
#          'в беседе с': 29,
#          'иностранных дел россии': 29,
#          '<start> как отметил': 29,
#          'интервью риа новости': 29,
#          '<start> до сих': 29,
#          'также что в': 29,
#          '<start> по утверждению': 29,
#          'в понедельник на': 29,
#          'с тех пор': 29,
#          'на пост мэра': 29,
#          'кандидатов в депутаты': 29,
#          'миллионов долларов в': 29,
#          'премьер-министр владимир путин': 29,
#          '<start> отвечая на': 28,
#          'на самом деле': 28,
#          'группировки федеральных сил': 28,
#          '<start> это решение': 28,
#          'получили ранения <end>': 28,
#          'в суд на': 28,
#          'при этом он': 28,
#          'в москве на': 28,
#          '<start> как отмечает': 28,
#          'в москве в': 28,
#          'один из них': 28,
#          'отвечая на вопрос': 27,
#          'объединенной группировки федеральных': 27,
#          'new york <end>': 27,
#          'в сша <end>': 27,
#          'в качестве кандидата': 27,
#          'что же касается': 27,
#          '<start> по ее': 27,
#          'миллиарда рублей <end>': 27,
#          '<start> речь идет': 27,
#          'в стране <end>': 27,
#          'в интервью риа': 27,
#          '<start> в целом': 27,
#          'сообщает агентство итар-тасс': 27,
#          'этом сообщает риа': 27,
#          'за доллар <end>': 27,
#          'принято решение о': 26,
#          'wall street journal': 26,
#          'не пострадал <end>': 26,
#          '<start> в тот': 26,
#          'первый заместитель министра': 26,
#          'решение было принято': 26,
#          '<start> в нем': 26,
#          'долларов сша <end>': 26,
#          'президента россии <end>': 26,
#          '<start> что же': 26,
#          'министра внутренних дел': 26,
#          'в том чтобы': 26,
#          'уголовное дело <end>': 26,
#          'в зависимости от': 26,
#          'рф владимир путин': 26,
#          'в случае если': 26,
#          'не может быть': 26,
#          'сообщает итар-тасс <end>': 26,
#          'эхо москвы со': 26,
#          'москвы со ссылкой': 26,
#          'международного валютного фонда': 25,
#          'заявил в интервью': 25,
#          '<start> по сообщениям': 25,
#          'об этом он': 25,
#          'сообщает bbc <end>': 25,
#          '<start> на сегодняшний': 25,
#          '<start> мы не': 25,
#          'минувшее воскресенье в': 25,
#          'управления по борьбе': 25,
#          'в результате чего': 25,
#          'в четверг на': 25,
#          'он напомнил что': 25,
#          'на территории россии': 25,
#          '100 миллионов долларов': 25,
#          'том что он': 25,
#          'по словам министра': 25,
#          'также отметил что': 25,
#          'и т д': 25,
#          'борьбе с терроризмом': 24,
#          'что в случае': 24,
#          'сообщили интерфаксу в': 24,
#          'во вторник на': 24,
#          'по делам печати': 24,
#          'что в ближайшее': 24,
#          'в обмен на': 24,
#          '<start> говоря о': 24,
#          'об этом говорится': 24,
#          'этом говорится в': 24,
#          'пост мэра москвы': 24,
#          'на месте происшествия': 24,
#          'связи с проблемой-2000': 24,
#          'с организованной преступностью': 24,
#          'в мире <end>': 24,
#          'в первом чтении': 24,
#          '<start> в этот': 24,
#          'не исключил что': 23,
#          'было принято решение': 23,
#          'как сообщили интерфаксу': 23,
#          'в чечне и': 23,
#          'в восточном тиморе': 23,
#          'заявил он <end>': 23,
#          'на место происшествия': 23,
#          '<start> судя по': 23,
#          'в любом случае': 23,
#          '<start> в пятницу': 23,
#          'на этот раз': 23,
#          'президент россии борис': 23,
#          'россии борис ельцин': 23,
#          'по подозрению в': 23,
#          'главного управления по': 23,
#          'министра иностранных дел': 23,
#          'федеральных сил в': 23,
#          '<start> он напомнил': 23,
#          'с 1 ноября': 23,
#          'в россии и': 23,
#          'к тому что': 23,
#          'министром иностранных дел': 23,
#          '<start> в своем': 23,
#          'заявил риа новости': 23,
#          'со своей стороны': 23,
#          'на северный кавказ': 23,
#          'по мнению экспертов': 23,
#          'в интервью корреспонденту': 23,
#          '<start> в пресс-службе': 23,
#          'кандидатом на пост': 23,
#          'в новогоднюю ночь': 23,
#          'для участия в': 22,
#          'на вопрос о': 22,
#          'во второй половине': 22,
#          'об этом сообщила': 22,
#          'на общую сумму': 22,
#          'не только в': 22,
#          'об этом журналистам': 22,
#          'в ночь с': 22,
#          'в воскресенье в': 22,
#          'по чрезвычайным ситуациям': 22,
#          'по их словам': 22,
#          'корреспонденту риа новости': 22,
#          '<start> в настоящий': 22,
#          'говорится в заявлении': 22,
#          'в среду на': 22,
#          'в верховный суд': 22,
#          'минувший четверг в': 22,
#          'цик александр вешняков': 22,
#          'долларов в год': 22,
#          'о создании союзного': 22,
#          '<start> по факту': 22,
#          'агентство новостей со': 22,
#          'агентство новостей <end>': 22,
#          'ссылкой на пресс-центр': 21,
#          'по данным агентства': 21,
#          '<start> на место': 21,
#          'в возрасте от': 21,
#          'без вести <end>': 21,
#          'за минувшие сутки': 21,
#          'в течение двух': 21,
#          '<start> по оценкам': 21,
#          'сообщили в пресс-службе': 21,
#          'никто не пострадал': 21,
#          'не будет <end>': 21,
#          'минувший вторник в': 21,
#          'в борьбе с': 21,
#          'территории чечни <end>': 21,
#          'владимир путин подписал': 21,
#          'московскому времени в': 21,
#          'на этой неделе': 21,
#          'по электронной почте': 21,
#          'закона о выборах': 21,
#          'в федеральный бюджет': 21,
#          '<start> в прошлом': 21,
#          'к выводу что': 21,
#          'один из лидеров': 21,
#          'создании союзного государства': 21,
#          'ноября 1999 года': 21,
#          'в субботу в': 21,
#          'сообщает агентство росбизнесконсалтинг': 21,
#          'в чеченской республике': 21,
#          'служба ввс <end>': 21,
#          'исполняющий обязанности президента': 21,
#          'на данный момент': 20,
#          'в ходе встречи': 20,
#          'что речь идет': 20,
#          'по связям с': 20,
#          '<start> после того': 20,
#          '<start> в воскресенье': 20,
#          'между тем в': 20,
#          'участия в выборах': 20,
#          'передает эхо москвы': 20,
#          'наступлением 2000 года': 20,
#          'заявил в среду': 20,
#          'владимира путина <end>': 20,
#          'в этом случае': 20,
#          'не исключают что': 20,
#          'это означает что': 20,
#          'по информации риа': 20,
#          'информации риа новости': 20,
#          'сообщает агентство reuters': 20,
#          'борьбе с организованной': 20,
#          'октября 1999 года': 20,
#          'мэра москвы юрия': 20,
#          'москвы юрия лужкова': 20,
#          'к 2000 году': 20,
#          'на то чтобы': 20,
#          'как сообщает associated': 20,
#          'средства массовой информации': 20,
#          'федеральных сил на': 20,
#          '1999 года в': 20,
#          'не исключает что': 20,
#          'доступ в интернет': 20,
#          'что несмотря на': 20,
#          'с проблемой-2000 <end>': 20,
#          'договора о создании': 20,
#          'в это время': 20,
#          '<start> к тому': 20,
#          'штабе объединенной группировки': 20,
#          'обязанности президента россии': 20,
#          'mp 3 com': 20,
#          'на выборах в': 19,
#          'по вопросу о': 19,
#          'средствах массовой информации': 19,
#          '<start> не исключено': 19,
#          '<start> вопрос о': 19,
#          'между тем как': 19,
#          '<start> а в': 19,
#          'также заявил что': 19,
#          'блок отечество вся': 19,
#          'федерального закона о': 19,
#          'сентября 1999 года': 19,
#          'эфире радиостанции эхо': 19,
#          'в частности по': 19,
#          'в полном объеме': 19,
#          'по ее словам': 19,
#          'мэра москвы <end>': 19,
#          'по данным на': 19,
#          'за последние два': 19,
#          'за тонну <end>': 19,
#          'в причастности к': 19,
#          'в пятницу на': 19,
#          '<start> так в': 19,
#          'этого года <end>': 19,
#          'на состоявшейся в': 19,
#          'вся россия <end>': 19,
#          'кроме того как': 19,
#          'как сообщает эхо': 19,
#          'различной степени тяжести': 19,
#          'во втором чтении': 19,
#          'в нынешнем году': 19,
#          'к наступлению 2000': 19,
#          'наступлению 2000 года': 19,
#          'доллара за баррель': 19,
#          'центральная избирательная комиссия': 19,
#          '<start> за это': 19,
#          'группировки на северном': 19,
#          'в госдуму <end>': 19,
#          'и ленинградской области': 19,
#          'как заявил журналистам': 19,
#          'на том что': 19,
#          'сообщает агентство военных': 19,
#          'в штабе объединенной': 19,
#          'заявил журналистам риа': 19,
#          'после встречи с': 18,
#          'как говорится в': 18,
#          'выборах в госдуму': 18,
#          'президента российской федерации': 18,
#          'речь идет об': 18,
#          '<start> как утверждает': 18,
#          'московской области <end>': 18,
#          'в ходе операции': 18,
#          'является одним из': 18,
#          'во вторник <end>': 18,
#          'по некоторым данным': 18,
#          'беседе с журналистами': 18,
#          'как передает итар-тасс': 18,
#          'том числе в': 18,
#          'риа новости начальник': 18,
#          'напомнил что в': 18,
#          'что по его': 18,
#          'для борьбы с': 18,
#          'россии владимира путина': 18,
#          'тот факт что': 18,
#          'в россию <end>': 18,
#          'средств массовой информации': 18,
#          'в течение года': 18,
#          'к уголовной ответственности': 18,
#          'мвд россии <end>': 18,
#          'размера оплаты труда': 18,
#          'тысяч рублей <end>': 18,
#          'в данном случае': 18,
#          'за рубежом <end>': 18,
#          'председателя совета директоров': 18,
#          'в 1994 году': 18,
#          'по состоянию на': 18,
#          'московскому времени <end>': 18,
#          'в грозном <end>': 18,
#          'министерства обороны россии': 18,
#          'президента россии владимир': 18,
#          'на всей территории': 17,
#          'прошлого года <end>': 17,
#          'по шкале рихтера': 17,
#          'второй половине дня': 17,
#          'подчеркнул что в': 17,
#          '<start> по оценке': 17,
#          'на борту самолета': 17,
#          'российской федерации в': 17,
#          'как сообщает bbc': 17,
#          'по сообщению риа': 17,
#          'сообщению риа новости': 17,
#          'в течение последних': 17,
#          'стало известно что': 17,
#          '<start> все они': 17,
#          'делам печати телерадиовещания': 17,
#          'печати телерадиовещания и': 17,
#          'телерадиовещания и средств': 17,
#          'и средств массовых': 17,
#          '<start> в ближайшее': 17,
#          '<start> у нас': 17,
#          'состоит в том': 17,
#          'этом сообщает итар-тасс': 17,
#          'главы государства <end>': 17,
#          'в последние годы': 17,
#          'об этом интерфаксу': 17,
#          'в 1993 году': 17,
#          'так и в': 17,
#          'в течение 10': 17,
#          'с наступлением 2000': 17,
#          '19 декабря <end>': 17,
#          'тем более что': 17,
#          'центральной избирательной комиссии': 17,
#          'передает интерфакс <end>': 17,
#          'в среднем на': 17,
#          'в два раза': 17,
#          '<start> за последние': 17,
#          '<start> я не': 17,
#          'внутренних дел россии': 17,
#          '<start> по последним': 17,
#          '<start> однако он': 17,
#          '<start> в конце': 17,
#          '<start> владимир путин': 17,
#          'в течение нескольких': 17,
#          'по месту жительства': 17,
#          'заявил на пресс-конференции': 17,
#          'в среду вечером': 17,
#          'топлива и энергетики': 17,
#          'он также сообщил': 17,
#          'юрия лужкова <end>': 17,
#          'заявил во вторник': 17,
#          'с одной стороны': 17,
#          '<start> по некоторым': 17,
#          'в ответ на': 17,
#          '<start> помимо этого': 17,
#          'текущего года <end>': 17,
#          'по словам главы': 17,
#          'ссылкой на источник': 17,
#          'на источник в': 17,
#          'на 1999 год': 17,
#          '<start> в ответ': 17,
#          'беженцев из чечни': 17,
#          'в европе <end>': 17,
#          '<start> выступая на': 17,
#          '<start> он не': 17,
#          'федеральных войск на': 17,
#          'заявил что не': 17,
#          'правительства россии в': 17,
#          'этом сообщает агентство': 17,
#          'кандидатом в президенты': 17,
#          'в тяжелом состоянии': 16,
#          'из-за того что': 16,
#          'в интервью интерфаксу': 16,
#          'то что в': 16,
#          'по мнению специалистов': 16,
#          'единой торговой сессии': 16,
#          'совета безопасности оон': 16,
#          '<start> как сообщают': 16,
#          'в интервью газете': 16,
#          '<start> для этого': 16,
#          'депутатов государственной думы': 16,
#          'об этом сегодня': 16,
#          'риа новости из': 16,
#          '<start> до этого': 16,
#          'с другой стороны': 16,
#          'в последние дни': 16,
#          'средств массовых коммуникаций': 16,
#          'ссылкой на представителя': 16,
#          'как сообщили журналистам': 16,
#          '<start> на заседании': 16,
#          'по сообщению агентства': 16,
#          'соответствии с законом': 16,
#          'он сказал что': 16,
#          'в 1992 году': 16,
#          'мэра и вице-мэра': 16,
#          '<start> правоохранительные органы': 16,
#          'из источников в': 16,
#          'и другие <end>': 16,
#          'сообщает радиостанция эхо': 16,
#          '<start> как отмечают': 16,
#          'государственного таможенного комитета': 16,
#          'на каширском шоссе': 16,
#          'по словам путина': 16,
#          'на следующий день': 16,
#          '00 по московскому': 16,
#          '<start> на этом': 16,
#          '<start> в состав': 16,
#          'о том как': 16,
#          '<start> никто из': 16,
#          'при этом что': 16,
#          'в прошлом месяце': 16,
#          'он пояснил что': 16,
#          '<start> как известно': 16,
#          'не в состоянии': 16,
#          'в одной из': 16,
#          'по этому делу': 16,
#          'минимального размера оплаты': 16,
#          'подписал указ о': 16,
#          'минувшую среду в': 16,
#          'из чечни <end>': 16,
#          '<start> по всей': 16,
#          'но и в': 16,
#          'по правам человека': 16,
#          'электронной коммерции <end>': 16,
#          'на срок до': 16,
#          'reuters со ссылкой': 16,
#          '<start> в письме': 16,
#          '<start> в субботу': 16,
#          'рбк со ссылкой': 16,
#          'дело по статье': 16,
#          'на брифинге в': 16,
#          'органов внутренних дел': 16,
#          'cnet news com': 16,
#          'кандидата на пост': 16,
#          'сил на северном': 16,
#          'агентству военных новостей': 16,
#          'напомним что ранее': 16,
#          'в президенты россии': 16,
#          'данным риа новости': 15,
#          'с терроризмом <end>': 15,
#          'пресс-конференции в москве': 15,
#          'в этом районе': 15,
#          'в боевых действиях': 15,
#          'в доме правительства': 15,
#          'в этой стране': 15,
#          'в ходе проверки': 15,
#          'в дагестане <end>': 15,
#          'в течение месяца': 15,
#          'как отмечается в': 15,
#          '<start> к сожалению': 15,
#          'взрывное устройство <end>': 15,
#          '<start> все эти': 15,
#          '<start> однако на': 15,
#          'в тот момент': 15,
#          '<start> он считает': 15,
#          'по окончании встречи': 15,
#          '<start> как сказал': 15,
#          'качестве кандидата на': 15,
#          'по делу о': 15,
#          'человек в том': 15,
#          'чеченской республики <end>': 15,
#          'на месте <end>': 15,
#          'сша мадлен олбрайт': 15,
#          'по всей стране': 15,
#          'ссылкой на начальника': 15,
#          'в этот же': 15,
#          'государственной думы <end>': 15,
#          'на одном из': 15,
#          'начальник главного управления': 15,
#          '<start> в москве': 15,
#          'владимира путина с': 15,
#          'до конца года': 15,
#          '<start> ранее в': 15,
#          'в четверг вечером': 15,
#          'что в россии': 15,
#          'стало известно риа': 15,
#          'известно риа новости': 15,
#          'с россией <end>': 15,
#          'заявил журналистам что': 15,
#          'вечером в минувший': 15,
#          'террористических актов <end>': 15,
#          'сообщил на пресс-конференции': 15,
#          '<start> в последнее': 15,
#          'российской федерации и': 15,
#          'россии и сша': 15,
#          'информацию о том': 15,
#          'ситуации в чечне': 15,
#          '2000 года в': 15,
#          '<start> он пояснил': 15,
#          'депутаты государственной думы': 15,
#          'как сообщает reuters': 15,
#          'московский городской суд': 15,
#          'наш дом россия': 15,
#          'этом заявил в': 15,
#          '<start> борис ельцин': 15,
#          'выборы в россии': 15,
#          'первый заместитель начальника': 15,
#          'в текущем году': 15,
#          'за счет средств': 15,
#          'на мировом рынке': 15,
#          'напомним что на': 15,
#          'о внесении изменений': 15,
#          'того по словам': 15,
#          'участие в выборах': 15,
#          'в следующем году': 15,
#          'доступа в интернет': 15,
#          'кандидата в президенты': 15,
#          'кандидатом в депутаты': 15,
#          'на участие в': 15,
#          'председатель цик александр': 15,
#          'всемирной торговой организации': 15,
#          'в сфере высоких': 15,
#          'сфере высоких технологий': 15,
#          '<start> в общей': 15,
#          '<start> в начале': 15,
#          'wired news <end>': 15,
#          'блоков и объединений': 15,
#          'по делам беженцев': 15,
#          'объединенной группировки на': 15,
#          'россии в чечне': 15,
#          'пост президента россии': 15,
#          'по данным риа': 14,
#          '<start> в отношении': 14,
#          'что в ближайшие': 14,
#          'так же как': 14,
#          '<start> в россии': 14,
#          'центра общественных связей': 14,
#          'кроме того на': 14,
#          'заявил что он': 14,
#          'бориса ельцина <end>': 14,
#          'миллионов долларов на': 14,
#          'в bank of': 14,
#          'в минувшую пятницу': 14,
#          'внутренних дел рф': 14,
#          '<start> как отмечается': 14,
#          'что в течение': 14,
#          '<start> на борту': 14,
#          'на территории республики': 14,
#          '<start> это не': 14,
#          'этом он заявил': 14,
#          'и московской области': 14,
#          'правоохранительных органов <end>': 14,
#          'этом сообщил сегодня': 14,
#          'председатель совета директоров': 14,
#          'миллионов долларов сша': 14,
#          '<start> общая сумма': 14,
#          '<start> на встрече': 14,
#          'на заседании правительства': 14,
#          'за 1999 год': 14,
#          'в пятницу <end>': 14,
#          'передает итар-тасс <end>': 14,
#          'заявление в котором': 14,
#          'к тому чтобы': 14,
#          'сообщил в понедельник': 14,
#          'в интернет <end>': 14,
#          'по данным газеты': 14,
#          'а также о': 14,
#          'в течение трех': 14,
#          'во всем мире': 14,
#          'этот же день': 14,
#          'следствия по делу': 14,
#          'в том случае': 14,
#          '<start> на сайте': 14,
#          'так как в': 14,
#          '<start> если бы': 14,
#          'в минувшие сутки': 14,
#          'что во время': 14,
#          'однако как сообщает': 14,
#          'по словам источника': 14,
#          'в течение ближайших': 14,
#          'и в частности': 14,
#          '<start> риа новости': 14,
#          'к концу года': 14,
#          '<start> он был': 14,
#          '<start> в штабе': 14,
#          'по словам первого': 14,
#          'по последним данным': 14,
#          'риа новости на': 14,
#          'у нас есть': 14,
#          'на территорию чечни': 14,
#          'и таким образом': 14,
#          'из россии <end>': 14,
#          'во втором туре': 14,
#          'нтв со ссылкой': 14,
#          'ситуации на северном': 14,
#          'сообщило риа новости': 14,
#          'министр обороны игорь': 14,
#          'обороны игорь сергеев': 14,
#          '2000 году <end>': 14,
#          'массовой информации <end>': 14,
#          'в будущем году': 14,
#          'госдумы геннадий селезнев': 14,
#          '<start> у него': 14,
#          'течение 10 дней': 14,
#          'верховный суд россии': 14,
#          '<start> для того': 14,
#          'заявил в понедельник': 14,
#          'он считает что': 14,
#          'информация о том': 14,
#          'в конце концов': 14,
#          'федеральный закон о': 14,
#          'внутренних дел и': 14,
#          'об этом сообщило': 14,
#          'евро за тонну': 14,
#          'судя по всему': 14,
#          'цен на нефть': 14,
#          'рублей за доллар': 14,
#          'в ходе следствия': 14,
#          'отметил также что': 14,
#          '<start> в отличие': 14,
#          'в чечне в': 14,
#          'по сообщению итар-тасс': 14,
#          'такое решение было': 14,
#          'связи с наступлением': 14,
#          'по всей видимости': 14,
#          '31 декабря 1999': 14,
#          '<start> на этот': 14,
#          'из федерального списка': 14,
#          'как заявил на': 14,
#          'по делу об': 14,
#          'в депутаты государственной': 14,
#          'отметил он <end>': 14,
#          'же время по': 14,
#          'сообщает агентство associated': 14,
#          'сообщает рбк со': 14,
#          'с преступлениями в': 14,
#          'оон по делам': 14,
#          'группировки войск на': 14,
#          'агентства военных новостей': 14,
#          'месяцев 1999 года': 14,
#          'на 30 процентов': 14,
#          'кандидатов на пост': 14,
#          'о выборах президента': 14,
#          'в отставку <end>': 14,
#          'кандидатов в президенты': 14,
#          'по антимонопольному иску': 14,
#          'сообщает cnet news': 14,
#          '1997 года <end>': 13,
#          'через bank of': 13,
#          'общественных связей фсб': 13,
#          'сегодня на пресс-конференции': 13,
#          'балла по шкале': 13,
#          'шкале рихтера <end>': 13,
#          'внутренних войск мвд': 13,
#          'пресс-центре объединенной группировки': 13,
#          'президента рф <end>': 13,
#          'сообщил в интервью': 13,
#          '<start> как заявили': 13,
#          'вне зависимости от': 13,
#          '<start> сейчас в': 13,
#          'в косово <end>': 13,
#          'говорится в документе': 13,
#          'в сша и': 13,
#          'в 20 километрах': 13,
#          'между тем по': 13,
#          '<start> они были': 13,
#          'в противном случае': 13,
#          'прибывшие на место': 13,
#          'его словам это': 13,
#          'сотрудники правоохранительных органов': 13,
#          '<start> по итогам': 13,
#          'президента сша билла': 13,
#          'сша билла клинтона': 13,
#          'corriere della sera': 13,
#          'с тем как': 13,
#          'на пост главы': 13,
#          'на ближнем востоке': 13,
#          'однако по его': 13,
#          '<start> в итоге': 13,
#          'администрации президента рф': 13,
#          'в москву <end>': 13,
#          'в россии в': 13,
#          'с космодрома байконур': 13,
#          'об этом итар-тасс': 13,
#          'том случае если': 13,
#          'квадратных метров <end>': 13,
#          'на 19 декабря': 13,
#          'избирательной кампании <end>': 13,
#          'что в связи': 13,
#          'в суд с': 13,
#          'к настоящему времени': 13,
#          'на следующей неделе': 13,
#          '<start> в сентябре': 13,
#          '<start> в документе': 13,
#          'заключается в том': 13,
#          'в своем выступлении': 13,
#          'по особо важным': 13,
#          'минувший понедельник в': 13,
#          '<start> в первую': 13,
#          'но не менее': 13,
#          'выразил уверенность что': 13,
#          'от участия в': 13,
#          '<start> как считает': 13,
#          '<start> министр обороны': 13,
#          'как сообщили корреспонденту': 13,
#          'что в этом': 13,
#          'государственная дума приняла': 13,
#          '<start> но в': 13,
#          'что это не': 13,
#          '<start> со своей': 13,
#          'через интернет <end>': 13,
#          'в этот день': 13,
#          '<start> как подчеркнул': 13,
#          '<start> вслед за': 13,
#          'риа новости пресс-секретарь': 13,
#          'в первом туре': 13,
#          'добавил он <end>': 13,
#          'до настоящего времени': 13,
#          'на данном этапе': 13,
#          'за прошлый год': 13,
#          'сообщает wired news': 13,
#          '<start> из них': 13,
#          'mars climate orbiter': 13,
#          ...})

# %%
def compute_joint_proba_markov_assumption(phrase, word_counts, bigram_counts):
    prob = 0
    for ngram in ngrammer(['<start>'] + normalize(phrase) + ['<end>']):
        word1, word2, word3 = ngram.split()
        if word1 in word_counts and ngram in bigram_counts:
            prob += np.log(bigram_counts[ngram]/word_counts[word1])
        else:
            prob += np.log(2e-5)
    
    return np.exp(prob)

# %%
compute_joint_proba_markov_assumption('красивый большой дом', unigrams_news, bigrams_news)
# Out:
# np.float64(7.999999999999997e-15)

# %%
matrix_news = lil_matrix((len(unigrams_news), 
                        len(unigrams_news)))

id2word_news = list(unigrams_news)
word2id_news = {word:i for i, word in enumerate(id2word_news)}



for ngram in bigrams_news:
    word1, word2, word3 = ngram.split()
    matrix_news[word2id_news[word1], word2id_news[word2]] =  (bigrams_news[ngram]/
                                                                     unigrams_news[word1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /workspaces/i-love-crispy-laptops/CompLing/CompLing7 - LangModel/23.01.2025.ipynb Ячейка 16 line 1
#       <a href='vscode-notebook-cell://codespaces%2Bimproved-system-x7rw5prr94v3wrj/workspaces/i-love-crispy-laptops/CompLing/CompLing7%20-%20LangModel/23.01.2025.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> word2id_news = {word:i for i, word in enumerate(id2word_news)}
#       <a href='vscode-notebook-cell://codespaces%2Bimproved-system-x7rw5prr94v3wrj/workspaces/i-love-crispy-laptops/CompLing/CompLing7%20-%20LangModel/23.01.2025.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> for ngram in bigrams_news:
# ---> <a href='vscode-notebook-cell://codespaces%2Bimproved-system-x7rw5prr94v3wrj/workspaces/i-love-crispy-laptops/CompLing/CompLing7%20-%20LangModel/23.01.2025.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>     word1, word2 = ngram.split()
#      <a href='vscode-notebook-cell://codespaces%2Bimproved-system-x7rw5prr94v3wrj/workspaces/i-love-crispy-laptops/CompLing/CompLing7%20-%20LangModel/23.01.2025.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     matrix_news[word2id_news[word1], word2id_news[word2]] =  (bigrams_news[ngram]/
#      <a href='vscode-notebook-cell://codespaces%2Bimproved-system-x7rw5prr94v3wrj/workspaces/i-love-crispy-laptops/CompLing/CompLing7%20-%20LangModel/23.01.2025.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>                                                                      unigrams_news[word1])
#
# ValueError: too many values to unpack (expected 2)

# %%
matrix_news
# Out:
# <List of Lists sparse matrix of dtype 'float64'
# 	with 380448 stored elements and shape (71987, 71987)>
#   Coords	Values
#   (0, 1)	0.00015691689681144864
#   (0, 2)	0.00354632186793874
#   (0, 4)	0.004268139593271403
#   (0, 9)	3.138337936228973e-05
#   (0, 10)	3.138337936228973e-05
#   (0, 12)	0.006935726839066031
#   (0, 14)	0.004770273663068039
#   (0, 20)	0.10158799899573186
#   (0, 24)	9.41501380868692e-05
#   (0, 25)	3.138337936228973e-05
#   (0, 29)	0.0002196836555360281
#   (0, 31)	0.00025106703489831785
#   (0, 35)	6.276675872457946e-05
#   (0, 39)	6.276675872457946e-05
#   (0, 43)	0.005962842078835049
#   (0, 46)	0.00025106703489831785
#   (0, 47)	0.00012553351744915893
#   (0, 49)	0.08024730102937484
#   (0, 50)	3.138337936228973e-05
#   (0, 51)	0.0011298016570424304
#   (0, 62)	3.138337936228973e-05
#   (0, 63)	3.138337936228973e-05
#   (0, 65)	3.138337936228973e-05
#   (0, 67)	0.009634697464222948
#   (0, 74)	0.0010984182776801407
#   :	:
#   (71962, 14)	1.0
#   (71963, 71964)	1.0
#   (71964, 33972)	1.0
#   (71965, 2)	1.0
#   (71966, 38013)	1.0
#   (71967, 297)	1.0
#   (71968, 9768)	1.0
#   (71969, 49)	1.0
#   (71970, 71971)	1.0
#   (71971, 9)	1.0
#   (71972, 58331)	1.0
#   (71973, 859)	1.0
#   (71974, 23529)	1.0
#   (71975, 633)	1.0
#   (71976, 71977)	1.0
#   (71977, 14)	1.0
#   (71978, 9)	1.0
#   (71979, 18209)	1.0
#   (71980, 1614)	1.0
#   (71981, 4)	1.0
#   (71982, 4352)	1.0
#   (71983, 20)	1.0
#   (71984, 1274)	1.0
#   (71985, 20)	1.0
#   (71986, 9)	1.0

# %%
def generate(matrix, id2word, word2id, n=100, start='<start>'):
    text = []
    current_idx = word2id[start]
    
    for i in range(n):
        
        chosen = np.random.choice(matrix.shape[1], p=matrix[current_idx].toarray()[0])
        # просто выбирать наиболее вероятное продолжение не получится
        # можете попробовать раскоментировать следующую строчку и посмотреть что получается
#         chosen = matrix[current_idx].argmax()
        text.append(id2word[chosen])
        
        if id2word[chosen] == '<end>':
            chosen = word2id['<start>']
        current_idx = chosen
    
    return ' '.join(text)

# %%
print(generate(matrix_news, id2word_news, word2id_news).replace('<end>', '\n'))
# Out:
# вторая по вопросам
#  мэор собирается штурмовать грозный и медперсонала
#  по решению проблемы нагорного карабаха
#  листовки долетели далеко не так как сообщает associated press 102 человека не видел ничего катастрофического не верят в палау центральная избирательная комиссия шамгара расследовавшей историю о крушении
#  министр иностранных дел ливана заблокировало импорт за границу двух третей американских инвестиций примерно 10 самых кровавых в ситуации среди сил направил дело будет в настоящий момент осуществляют перегруппировку сил на черно-белых фотографиях были убиты около трети американцев расходовать свои дома не следует реклама мыла выросло до сих пор было никаких опасных преступников
#  сделка 29
